# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3 as sql
# %matplotlib inline
import folium

# %%
police_prec = pd.read_csv('../data/Police_Precincts.csv')

# %%
police_prec.head(5)
# Out:
#             Precinct Name           Precinct Commander  \
# 0           West Precinct       Commander David Corman
# 1          South Precinct     Commander Keith Stephens
# 2  Midtown Hills Precinct      Commander Tommy Widener
# 3        Central Precinct     Commander Jason Starling
# 4           East Precinct  Commander Virginia Carrigan
#
#        Community Coordinator    Phone Number                     Street  \
# 0      Sergeant John Bourque  (615) 862-7747        5500 Charlotte Pike
# 1  Sergeant Deniz Ismailovic  (615) 862-7744         5101 Harding Place
# 2   Sergeant Catherine Poole  (615) 880-1411     1441 12th Avenue South
# 3       Sergeant Misty Hobbs  (615) 862-7611  601 Korean Veterans Blvd.
# 4      Sergeant Jessica Ware  (615) 862-7600        936 E. Trinity Lane
#
#         City State                                            Website  \
# 0  Nashville    TN  http://www.nashville.gov/Police-Department/Pre...
# ...

# %%
traffic_acc = pd.read_csv('../data/Traffic_Accidents.csv', low_memory=False)

traffic_acc.head(5)
# Out:
#    Accident Number                Date and Time  Number of Motor Vehicles  \
# 0      20200606233  September 21, 2020 06:37 PM                       1.0
# 1      20200603908  September 20, 2020 12:00 AM                       1.0
# 2      20200604395  September 20, 2020 07:20 PM                       1.0
# 3      20200605021  September 21, 2020 05:58 AM                       2.0
# 4      20200605988  September 21, 2020 03:27 PM                       2.0
#
#    Number of Injuries  Number of Fatalities Property Damage Hit and Run  \
# 0                   0                     0             NaN       False
# 1                   0                     0            True        True
# 2                   1                     0             NaN       False
# 3                   0                     0             NaN       False
# 4                   0                     0             NaN       False
#
#    Reporting Officer  Collision Type Code  \
# ...

# %%
traffic_acc.describe()
# Out:
#        Accident Number  Number of Motor Vehicles  Number of Injuries  \
# count     2.182330e+05             218232.000000       218233.000000
# mean      2.017898e+10                  1.867155            0.388566
# std       1.997366e+07                  0.674301            0.761444
# min       2.010081e+10                  0.000000            0.000000
# 25%       2.016078e+10                  2.000000            0.000000
# 50%       2.018028e+10                  2.000000            0.000000
# 75%       2.019078e+10                  2.000000            1.000000
# max       2.022030e+10                 27.000000           35.000000
#
#        Number of Fatalities  Reporting Officer  Collision Type Code  \
# count              218233.0       2.182230e+05        218217.000000
# mean                    0.0       4.811087e+05             7.226586
# std                     0.0       7.042650e+05            10.709838
# min                     0.0       1.000000e+00             0.000000
# ...

# %%
traffic_acc['Date and Time'].nsmallest
# Out:
# <bound method Series.nsmallest of 0         September 21, 2020 06:37 PM
# 1         September 20, 2020 12:00 AM
# 2         September 20, 2020 07:20 PM
# 3         September 21, 2020 05:58 AM
# 4         September 21, 2020 03:27 PM
#                      ...
# 218228      October 10, 2021 08:53 PM
# 218229      October 10, 2021 01:24 AM
# 218230      October 10, 2021 02:30 PM
# 218231      October 10, 2021 12:00 AM
# 218232      October 10, 2021 02:00 AM
# Name: Date and Time, Length: 218233, dtype: object>

# %%
metro_survey = pd.read_csv('../data/Metro_Resident_Survey_Responses.csv')

metro_survey.head(5)
# Out:
#    Period  Start Date    End Date  ZIP Code           Service District  \
# 0  2018Q2  06/21/2018  07/16/2018     37208    Urban Services District
# 1  2018Q2  06/21/2018  07/16/2018     37211    Urban Services District
# 2  2018Q2  06/21/2018  07/16/2018     37208    Urban Services District
# 3  2018Q2  06/21/2018  07/16/2018     37203    Urban Services District
# 4  2018Q1  02/01/2018  03/06/2018     37138  General Services District
#
#   Quality of Life Overall Feeling of Safety Neighborhood Safety  \
# 0         Neutral                   Neutral             Neutral
# 1       Satisfied                 Satisfied           Satisfied
# 2  Very Satisfied                   Neutral           Satisfied
# 3       Satisfied            Very Satisfied           Satisfied
# 4       Satisfied                 Satisfied           Satisfied
#
#   City Appearance Neighborhood Appearance  ... Race / Ethnicity - Black  \
# 0         Neutral               Satisfied  ...                      Yes
# ...

# %%
metro_survey.columns.to_list()
# Out:
# ['Period',
#  'Start Date',
#  'End Date',
#  'ZIP Code',
#  'Service District',
#  'Quality of Life',
#  'Overall Feeling of Safety',
#  'Neighborhood Safety',
#  'City Appearance',
#  'Neighborhood Appearance',
#  'Nashville as Residence',
#  'Nashville as Place to Raise Children',
#  'Nashville as Workplace',
#  'Nashville as Place to Start/Grow Business',
#  'Nashville as Retirement Place',
#  'Metro Services - Overall',
#  'Value Received from Taxes',
#  'Elected Official Leadership',
#  'Elected Official Responsiveness',
#  'Elected Official Accessibility',
#  'Metro Transparency and Ethics',
#  'Metro Budgeting and Stewardship',
#  'Customer Service',
#  'Metro Communication',
#  'Decision Input Opportunity',
#  'Crime Prevention',
#  'Police - Overall',
#  'Fire and EMS - Overall',
#  'Streets and Sidewalks - Overall',
#  'Trash and Recycling - Overall',
#  'Public Education',
#  'Public Health - Overall',
#  'Public Library',
#  'Social Services - Overall',
# ...

# %%
metro_survey.dtypes
# Out:
# Period                                 object
# Start Date                             object
# End Date                               object
# ZIP Code                                int64
# Service District                       object
#                                         ...
# Race / Ethnicity - Other Definition    object
# Total Annual Household Income          object
# Age                                    object
# Gender Identity                        object
# Education Attained                     object
# Length: 181, dtype: object
